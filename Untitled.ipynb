# %%
import pandas as pd
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import re # library for regular expression operations
import string # for string operations
import numpy as np

from nltk.corpus import stopwords # module for stop words that come with NLTK
from nltk.stem import PorterStemmer # module for stemming
from nltk.tokenize import TweetTokenizer # module for tokenizing strings
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ragib\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Ragib\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data = pd.read_csv('datasets/trump_old_tweets.csv')

df = data.copy()

# %%
df.head(10)
# Out:
#                   date                                               text
# 0  2020-10-14 17:12:35  RT @HerschelWalker: GEORGIA, Let's go VOTE to ...
# 1  2020-10-14 14:55:48  RT @realDonaldTrump: Republicans will be provi...
# 2  2020-10-14 14:29:31  Georgia, this is your chance to MAKE AMERICA G...
# 3  2020-10-14 14:14:04  Fight hard Republicans. They have been taking ...
# 4  2020-10-14 12:52:34                            https://t.co/gsFSghkmdM
# 5  2020-10-14 05:31:59  RT @GaryCoby: YES! Watch... @GamebredFighter \...
# 6  2020-10-14 04:08:24  Great night in Pennsylvania. Big and Enthusias...
# 7  2020-10-14 03:47:57  Vote for Trump. Save your 2nd Amendment! https...
# 8  2020-10-14 03:45:48  RT @WAVY_News: A lawsuit seeking to extend Vir...
# 9  2020-10-14 03:43:25  Virginia, VOTE for President Trump and save yo...

# %% [markdown]
# ## 2.0 Preprocessing

# %% [markdown]
# When preprocessing, you have to perform the following:
#
# - Eliminate handles and URLs
# - Tokenize the string into words.
# - Remove stop words like "and, is, a, on, etc."
# - Stemming- or convert every word to its stem. Like dancer, dancing, danced, becomes 'danc'. You can use porter stemmer to take care of this.
# - Convert all your words to lower case
#
# For example the following tweet "@YMourri and @AndrewYNg are tuning a GREAT AI model at https://deeplearning.ai!!!" after preprocessing becomes [tun,great,ai,model]

# %%
def process_tweet(tweet):
    """Process tweet function.
    Input:
        tweet: a string containing a tweet
    Output:
        tweets_clean: a list of words containing the processed tweet

    """
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)

    tweets_clean = []
    for word in tweet_tokens:
        if (word not in stopwords_english and  # remove stopwords
                word not in string.punctuation):  # remove punctuation
            # tweets_clean.append(word)
            stem_word = stemmer.stem(word)  # stemming word
            tweets_clean.append(stem_word)

    return tweets_clean

# %%
df_tweets = df['text']
df_tweets.head()
# Out:
# 0    RT @HerschelWalker: GEORGIA, Let's go VOTE to ...
# 1    RT @realDonaldTrump: Republicans will be provi...
# 2    Georgia, this is your chance to MAKE AMERICA G...
# 3    Fight hard Republicans. They have been taking ...
# 4                              https://t.co/gsFSghkmdM
# Name: text, dtype: object

# %%
all_sentences = []

for word in df_tweets:
    all_sentences.append(word)

# %%
print(all_sentences)
# Out:
# ["RT @HerschelWalker: GEORGIA, Let's go VOTE to keep our Freedoms for the best country in the world! 🇺🇸🇺🇸🇺🇸@potus  #MAGA2020 #Trump2020 #KAG2…", 'RT @realDonaldTrump: Republicans will be providing far better Healthcare than the Democrats, at a far lower cost...And will always protect…', 'Georgia, this is your chance to MAKE AMERICA GREAT AGAIN. We have been strong for our Military, Vets, 2nd Amendment, and ALL. VOTE NOW!', 'Fight hard Republicans. They have been taking advantage of the system for years! https://t.co/vaToeGjrHG', 'https://t.co/gsFSghkmdM', 'RT @GaryCoby: YES! Watch... @GamebredFighter \n\n#MAGA #SuperBowl \n\nhttps://t.co/2bgAdkMFJv', 'Great night in Pennsylvania. Big and Enthusiastic Crowd. Will be back soon. VOTE!!!', 'Vote for Trump. Save your 2nd Amendment! https://t.co/QYt5K7oYws', 'RT @WAVY_News: A lawsuit seeking to extend Virginia’s voter registration deadline was filed Tuesday night after the state’s Department of E…', 'Virginia, VOTE for President Trump and save your under siege 2nd Amendment. https://t.co/V0AGM7gLaL', 'https://t.co/75J7mUX0Iy', 'RT @McguireScotty: This is Lee Keltner. He is the victim of the Denver shooting. He made cowboy hats.\n\nDenver has a DemocRat mayor\n\n Pray f…', 'RT @TaylerUSA: Yesterday in Denver a Conservative was executed by Matt Dolloff \n\n@DenverPolice claim he has no connections to ANTIFA, but t…', 'RT @stillgray: Extended sequence of events in Denver. The victim backed off. He never stood a chance. https://t.co/4HSSYQ1wrx', 'RT @BreitbartNews: Facebook has reportedly disabled the account of former U.S. Marine Corps Sergeant John “Tig” Tiegen, one of the men who…', 'RT @MrAndyNgo: Tonight the “indigenous” faction of antifa held a “day of rage” riot in Portland. They banned video recording as the crimina…', 'RT @VFL2013: Well... 🇺🇸👀🇺🇸👀🇺🇸👀', 'I will never let you down! #MAGA https://t.co/22qkatrJb2', 'RT @Seitzer1: UFC’s @GamebredFighter gives one of the best “vote for Trump” speeches I’ve heard!\nhttps://t.co/YstONQTYeF', 'https://t.co/wJN4zv0y8O', 'For years you had a President who apologized for America – now you have a President who is standing up for America, and standing up for Pennsylvania. So get your friends, get your family, get your neighbors, and GET OUT AND VOTE! https://t.co/gsFSgh2KPc https://t.co/xfZtBixRkk', 'Proud citizens like you helped build this Country—and together, we are taking back our Country. We are returning power to YOU, the American People! #MAGA https://t.co/rn69eJJAPV', 'This election is a simple choice: If Biden Wins, China Wins. When WE Win, YOU WIN, Pennsylvania WINS, and America WINS! https://t.co/dgx92ZxsBO', 'One of the most important issues for Pennsylvania is the survival of your fracking industry. Joe Biden has repeatedly pledged to abolish fracking. When asked about fracking, Biden said he would “make sure it’s ELIMINATED!” With me, you’re going to FRACK! https://t.co/tHt7Chh4jB', 'Thank you Johnstown, Pennsylvania! https://t.co/mdHfNODJCT', 'You mean only Democrats are allowed to do this? But haven’t the Dems been doing this for years? See you in court. Fight hard Republicans! https://t.co/vaToeGB2ze', 'Watch @OANN, @newsmax, @cspan. Just arrived in Pennsylvania. Enjoy!', 'Getting ready to land in Johnstown, Pennsylvania. Big crowd. See you soon!!!', 'Totally Negative China Virus Reports. Hit it early and hard. Fake News is devastated. They are very bad (and sick!) people!', '....protecting people with Pre-existing conditions. He has done nothing on Healthcare, cost or otherwise, or virtually anything else. An empty suit!!!', 'How dare failed Presidential Candidate (1% and falling!) @CoryBooker make false charges and statements about me in addressing Judge Barrett. Illegally, never even lived in Newark when he was Mayor. Guy is a total loser! I want better Healthcare for far less money, always.....', 'Early voting is underway in the Great States of GEORGIA and TEXAS. Find out where to early vote by clicking below! #MAGA http ...

# %%
#df_split
lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)


print(lines)
# Out:
# ['RT', '@HerschelWalker:', 'GEORGIA,', "Let's", 'go', 'VOTE', 'to', 'keep', 'our', 'Freedoms', 'for', 'the', 'best', 'country', 'in', 'the', 'world!', '🇺🇸🇺🇸🇺🇸@potus', '#MAGA2020', '#Trump2020', '#KAG2…', 'RT', '@realDonaldTrump:', 'Republicans', 'will', 'be', 'providing', 'far', 'better', 'Healthcare', 'than', 'the', 'Democrats,', 'at', 'a', 'far', 'lower', 'cost...And', 'will', 'always', 'protect…', 'Georgia,', 'this', 'is', 'your', 'chance', 'to', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN.', 'We', 'have', 'been', 'strong', 'for', 'our', 'Military,', 'Vets,', '2nd', 'Amendment,', 'and', 'ALL.', 'VOTE', 'NOW!', 'Fight', 'hard', 'Republicans.', 'They', 'have', 'been', 'taking', 'advantage', 'of', 'the', 'system', 'for', 'years!', 'https://t.co/vaToeGjrHG', 'https://t.co/gsFSghkmdM', 'RT', '@GaryCoby:', 'YES!', 'Watch...', '@GamebredFighter', '#MAGA', '#SuperBowl', 'https://t.co/2bgAdkMFJv', 'Great', 'night', 'in', 'Pennsylvania.', 'Big', 'and', 'Enthusiastic', 'Crowd.', 'Will', 'be', 'back', 'soon.', 'VOTE!!!', 'Vote', 'for', 'Trump.', 'Save', 'your', '2nd', 'Amendment!', 'https://t.co/QYt5K7oYws', 'RT', '@WAVY_News:', 'A', 'lawsuit', 'seeking', 'to', 'extend', 'Virginia’s', 'voter', 'registration', 'deadline', 'was', 'filed', 'Tuesday', 'night', 'after', 'the', 'state’s', 'Department', 'of', 'E…', 'Virginia,', 'VOTE', 'for', 'President', 'Trump', 'and', 'save', 'your', 'under', 'siege', '2nd', 'Amendment.', 'https://t.co/V0AGM7gLaL', 'https://t.co/75J7mUX0Iy', 'RT', '@McguireScotty:', 'This', 'is', 'Lee', 'Keltner.', 'He', 'is', 'the', 'victim', 'of', 'the', 'Denver', 'shooting.', 'He', 'made', 'cowboy', 'hats.', 'Denver', 'has', 'a', 'DemocRat', 'mayor', 'Pray', 'f…', 'RT', '@TaylerUSA:', 'Yesterday', 'in', 'Denver', 'a', 'Conservative', 'was', 'executed', 'by', 'Matt', 'Dolloff', '@DenverPolice', 'claim', 'he', 'has', 'no', 'connections', 'to', 'ANTIFA,', 'but', 't…', 'RT', '@stillgray:', 'Extended', 'sequence', 'of', 'events', 'in', 'Denver.', 'The', 'victim', 'backed', 'off.', 'He', 'never', 'stood', 'a', 'chance.', 'https://t.co/4HSSYQ1wrx', 'RT', '@BreitbartNews:', 'Facebook', 'has', 'reportedly', 'disabled', 'the', 'account', 'of', 'former', 'U.S.', 'Marine', 'Corps', 'Sergeant', 'John', '“Tig”', 'Tiegen,', 'one', 'of', 'the', 'men', 'who…', 'RT', '@MrAndyNgo:', 'Tonight', 'the', '“indigenous”', 'faction', 'of', 'antifa', 'held', 'a', '“day', 'of', 'rage”', 'riot', 'in', 'Portland.', 'They', 'banned', 'video', 'recording', 'as', 'the', 'crimina…', 'RT', '@VFL2013:', 'Well...', '🇺🇸👀🇺🇸👀🇺🇸👀', 'I', 'will', 'never', 'let', 'you', 'down!', '#MAGA', 'https://t.co/22qkatrJb2', 'RT', '@Seitzer1:', 'UFC’s', '@GamebredFighter', 'gives', 'one', 'of', 'the', 'best', '“vote', 'for', 'Trump”', 'speeches', 'I’ve', 'heard!', 'https://t.co/YstONQTYeF', 'https://t.co/wJN4zv0y8O', 'For', 'years', 'you', 'had', 'a', 'President', 'who', 'apologized', 'for', 'America', '–', 'now', 'you', 'have', 'a', 'President', 'who', 'is', 'standing', 'up', 'for', 'America,', 'and', 'standing', 'up', 'for', 'Pennsylvania.', 'So', 'get', 'your', 'friends,', 'get', 'your', 'family,', 'get', 'your', 'neighbors,', 'and', 'GET', 'OUT', 'AND', 'VOTE!', 'https://t.co/gsFSgh2KPc', 'https://t.co/xfZtBixRkk', 'Proud', 'citizens', 'like', 'you', 'helped', 'build', 'this', 'Country—and', 'together,', 'we', 'are', 'taking', 'back', 'our', 'Country.', 'We', 'are', 'returning', 'power', 'to', 'YOU,', 'the', 'American', 'People!', '#MAGA', 'https://t.co/rn69eJJAPV', 'This', 'election', 'is', 'a', 'simple', 'choice:', 'If', 'Biden', 'Wins,', 'China', 'Wins.', 'When', 'WE', 'Win,', 'YOU', 'WIN,', 'Pennsylvania', 'WINS,', 'and', 'America', 'WINS!', 'https://t.co/dgx92ZxsBO', 'One', 'of', 'the', 'most', 'important', 'issues', 'for', 'Pennsylvania', 'is', 'the', 'survival', 'of', 'your', 'fracking', 'industry.', 'Joe', 'Biden', 'has', 'repeatedly', 'pledged', 'to', 'abolish', 'fracking.', 'When', 'asked', 'about', 'fracking,', 'Biden', 'said', 'he', 'would', '“make', 'sure', 'it’s',  ...

# %%
rt = ['RT']

for word in list(lines):  # iterating on a copy since removing will mess things up
    if word in rt:
        lines.remove(word)

# %%
lines
# Out:
# ['@HerschelWalker:',
#  'GEORGIA,',
#  "Let's",
#  'go',
#  'VOTE',
#  'to',
#  'keep',
#  'our',
#  'Freedoms',
#  'for',
#  'the',
#  'best',
#  'country',
#  'in',
#  'the',
#  'world!',
#  '🇺🇸🇺🇸🇺🇸@potus',
#  '#MAGA2020',
#  '#Trump2020',
#  '#KAG2…',
#  '@realDonaldTrump:',
#  'Republicans',
#  'will',
#  'be',
#  'providing',
#  'far',
#  'better',
#  'Healthcare',
#  'than',
#  'the',
#  'Democrats,',
#  'at',
#  'a',
#  'far',
#  'lower',
#  'cost...And',
#  'will',
#  'always',
#  'protect…',
#  'Georgia,',
#  'this',
#  'is',
#  'your',
#  'chance',
#  'to',
#  'MAKE',
#  'AMERICA',
#  'GREAT',
#  'AGAIN.',
#  'We',
#  'have',
#  'been',
#  'strong',
#  'for',
#  'our',
#  'Military,',
#  'Vets,',
#  '2nd',
#  'Amendment,',
#  'and',
#  'ALL.',
#  'VOTE',
#  'NOW!',
#  'Fight',
#  'hard',
#  'Republicans.',
#  'They',
#  'have',
#  'been',
#  'taking',
#  'advantage',
#  'of',
#  'the',
#  'system',
#  'for',
#  'years!',
#  'https://t.co/vaToeGjrHG',
#  'https://t.co/gsFSghkmdM',
#  '@GaryCoby:',
#  'YES!',
#  'Watch...',
#  '@GamebredFighter',
#  '#MAGA',
#  '#SuperBowl',
#  'https://t.co/2bgAdkMFJv',
#  'Great',
#  'night',
#  'in',
#  'Pennsylvania.',
#  'Big',
#  'and',
#  'Enthusiastic',
#  'Crowd.',
#  'Will',
#  'be',
#  'back',
#  'soon.',
#  'VOTE!!!',
#  'Vote',
#  'for',
#  'Trump.',
#  'Save',
#  'your',
#  '2nd',
#  'Amendment!',
#  'https://t.co/QYt5K7oYws',
#  '@WAVY_News:',
#  'A',
#  'lawsuit',
#  'seeking',
#  'to',
#  'extend',
#  'Virginia’s',
#  'voter',
#  'registration',
#  'deadline',
#  'was',
#  'filed',
#  'Tuesday',
#  'night',
#  'after',
#  'the',
#  'state’s',
#  'Department',
#  'of',
#  'E…',
#  'Virginia,',
#  'VOTE',
#  'for',
#  'President',
#  'Trump',
#  'and',
#  'save',
#  'your',
#  'under',
#  'siege',
#  '2nd',
#  'Amendment.',
#  'https://t.co/V0AGM7gLaL',
#  'https://t.co/75J7mUX0Iy',
#  '@McguireScotty:',
#  'This',
#  'is',
#  'Lee',
#  'Keltner.',
#  'He',
#  'is',
#  'the',
#  'victim',
#  'of',
#  'the',
#  'Denver',
#  'shooting.',
#  'He',
#  'made',
#  'cowboy',
#  'hats.',
#  'Denver',
#  'has',
#  'a',
#  'DemocRat',
#  'mayor',
#  'Pray',
#  'f…',
#  '@TaylerUSA:',
#  'Yesterday',
#  'in',
#  'Denver',
#  'a',
#  'Conservative',
#  'was',
#  'executed',
#  'by',
#  'Matt',
#  'Dolloff',
#  '@DenverPolice',
#  'claim',
#  'he',
#  'has',
#  'no',
#  'connections',
#  'to',
#  'ANTIFA,',
#  'but',
#  't…',
#  '@stillgray:',
#  'Extended',
#  'sequence',
#  'of',
#  'events',
#  'in',
#  'Denver.',
#  'The',
#  'victim',
#  'backed',
#  'off.',
#  'He',
#  'never',
#  'stood',
#  'a',
#  'chance.',
#  'https://t.co/4HSSYQ1wrx',
#  '@BreitbartNews:',
#  'Facebook',
#  'has',
#  'reportedly',
#  'disabled',
#  'the',
#  'account',
#  'of',
#  'former',
#  'U.S.',
#  'Marine',
#  'Corps',
#  'Sergeant',
#  'John',
#  '“Tig”',
#  'Tiegen,',
#  'one',
#  'of',
#  'the',
#  'men',
#  'who…',
#  '@MrAndyNgo:',
#  'Tonight',
#  'the',
#  '“indigenous”',
#  'faction',
#  'of',
#  'antifa',
#  'held',
#  'a',
#  '“day',
#  'of',
#  'rage”',
#  'riot',
#  'in',
#  'Portland.',
#  'They',
#  'banned',
#  'video',
#  'recording',
#  'as',
#  'the',
#  'crimina…',
#  '@VFL2013:',
#  'Well...',
#  '🇺🇸👀🇺🇸👀🇺🇸👀',
#  'I',
#  'will',
#  'never',
#  'let',
#  'you',
#  'down!',
#  '#MAGA',
#  'https://t.co/22qkatrJb2',
#  '@Seitzer1:',
#  'UFC’s',
#  '@GamebredFighter',
#  'gives',
#  'one',
#  'of',
#  'the',
#  'best',
#  '“vote',
#  'for',
#  'Trump”',
#  'speeches',
#  'I’ve',
#  'heard!',
#  'https://t.co/YstONQTYeF',
#  'https://t.co/wJN4zv0y8O',
#  'For',
#  'years',
#  'you',
#  'had',
#  'a',
#  'President',
#  'who',
#  'apologized',
#  'for',
#  'America',
#  '–',
#  'now',
#  'you',
#  'have',
#  'a',
#  'President',
#  'who',
#  'is',
#  'standing',
#  'up',
#  'for',
#  'America,',
#  'and',
#  'standing',
#  'up',
#  'for',
#  'Pennsylvania.',
#  'So',
#  'get',
#  'your',
#  'friends,',
#  'get',
#  'your',
#  'family,',
#  'get',
#  'your',
#  'neighbors,',
#  'and',
#  'GET',
#  'OUT',
#  'AND',
#  'VOTE!',
#  'https://t.co/gsFSgh2KPc',
#  'https://t.co/xfZtBixRkk',
#  'Proud',
#  'citizens',
#  'like',
#  'you',
#  'helped',
#  'build',
#  'this',
#  'Country—and',
#  'together,',
#  'we',
#  'are',
#  'taking',
#  'back',
#  'our',
#  'Country.',
#  'We',
#  'are',
#  'returning',
#  'power',
#  'to',
#  'YOU,',
#  'the',
#  'American',
#  'People!',
#  '#MAGA',
#  'https://t.co/rn69eJJAPV',
#  'This',
#  'election',
#  'is',
#  'a',
#  'simple',
#  'choice:',
#  'If',
#  'Biden',
#  'Wins,',
#  'China',
#  'Wins.',
#  'When',
#  'WE',
#  'Win,',
#  'YOU',
#  'WIN,',
#  'Pennsylvania',
#  'WINS,',
#  'and',
#  'America',
#  'WINS!',
#  'https://t.co/dgx92ZxsBO',
#  'One',
#  'of',
#  'the',
#  'most',
#  'important',
#  'issues',
#  'for',
#  'Pennsylvania',
#  'is',
#  'the',
#  'survival',
#  'of',
#  'your',
#  'fracking',
#  'industry.',
#  'Joe',
#  'Biden',
#  'has',
#  'repeatedly',
#  'pledged',
#  'to',
#  'abolish',
#  'fracking.',
#  'When',
#  'asked',
#  'about',
#  'fracking,',
#  'Biden',
#  'said',
#  'he',
#  'would',
#  '“make',
#  'sure',
#  'it’s',
#  'ELIMINATED!”',
#  'With',
#  'me,',
#  'you’re',
#  'going',
#  'to',
#  'FRACK!',
#  'https://t.co/tHt7Chh4jB',
#  'Thank',
#  'you',
#  'Johnstown,',
#  'Pennsylvania!',
#  'https://t.co/mdHfNODJCT',
#  'You',
#  'mean',
#  'only',
#  'Democrats',
#  'are',
#  'allowed',
#  'to',
#  'do',
#  'this?',
#  'But',
#  'haven’t',
#  'the',
#  'Dems',
#  'been',
#  'doing',
#  'this',
#  'for',
#  'years?',
#  'See',
#  'you',
#  'in',
#  'court.',
#  'Fight',
#  'hard',
#  'Republicans!',
#  'https://t.co/vaToeGB2ze',
#  'Watch',
#  '@OANN,',
#  '@newsmax,',
#  '@cspan.',
#  'Just',
#  'arrived',
#  'in',
#  'Pennsylvania.',
#  'Enjoy!',
#  'Getting',
#  'ready',
#  'to',
#  'land',
#  'in',
#  'Johnstown,',
#  'Pennsylvania.',
#  'Big',
#  'crowd.',
#  'See',
#  'you',
#  'soon!!!',
#  'Totally',
#  'Negative',
#  'China',
#  'Virus',
#  'Reports.',
#  'Hit',
#  'it',
#  'early',
#  'and',
#  'hard.',
#  'Fake',
#  'News',
#  'is',
#  'devastated.',
#  'They',
#  'are',
#  'very',
#  'bad',
#  '(and',
#  'sick!)',
#  'people!',
#  '....protecting',
#  'people',
#  'with',
#  'Pre-existing',
#  'conditions.',
#  'He',
#  'has',
#  'done',
#  'nothing',
#  'on',
#  'Healthcare,',
#  'cost',
#  'or',
#  'otherwise,',
#  'or',
#  'virtually',
#  'anything',
#  'else.',
#  'An',
#  'empty',
#  'suit!!!',
#  'How',
#  'dare',
#  'failed',
#  'Presidential',
#  'Candidate',
#  '(1%',
#  'and',
#  'falling!)',
#  '@CoryBooker',
#  'make',
#  'false',
#  'charges',
#  'and',
#  'statements',
#  'about',
#  'me',
#  'in',
#  'addressing',
#  'Judge',
#  'Barrett.',
#  'Illegally,',
#  'never',
#  'even',
#  'lived',
#  'in',
#  'Newark',
#  'when',
#  'he',
#  'was',
#  'Mayor.',
#  'Guy',
#  'is',
#  'a',
#  'total',
#  'loser!',
#  'I',
#  'want',
#  'better',
#  'Healthcare',
#  'for',
#  'far',
#  'less',
#  'money,',
#  'always.....',
#  'Early',
#  'voting',
#  'is',
#  'underway',
#  'in',
#  'the',
#  'Great',
#  'States',
#  'of',
#  'GEORGIA',
#  'and',
#  'TEXAS.',
#  'Find',
#  'out',
#  'where',
#  'to',
#  'early',
#  'vote',
#  'by',
#  'clicking',
#  'below!',
#  '#MAGA',
#  'https://t.co/gsFSghkmdM',
#  'Happy',
#  '245th',
#  'Birthday',
#  'to',
#  'our',
#  'GREAT',
#  '@USNavy!',
#  '#Navy245',
#  'https://t.co/EEGIwCh0wD',
#  'Volunteer',
#  'to',
#  'be',
#  'a',
#  'Trump',
#  'Election',
#  'Poll',
#  'Watcher.',
#  'Sign',
#  'up',
#  'today!',
#  '#MakeAmericaGreatAgain',
#  'https://t.co/3AnrRV7uSz',
#  'Join',
#  'me',
#  'Friday',
#  '(10/16)',
#  'evening',
#  'at',
#  '7:00pmE',
#  'in',
#  'Macon,',
#  'Georgia',
#  'at',
#  'the',
#  'Middle',
#  'Georgia',
#  'Regional',
#  'Airport!',
#  '#MAGA',
#  'https://t.co/rZbqKTueVg',
#  'Join',
#  'me',
#  'Friday',
#  '(10/16)',
#  'in',
#  'Ocala,',
#  'Florida',
#  'at',
#  'the',
#  'Ocala',
#  'International',
#  'Airport',
#  'at',
#  '4:00pmE!',
#  '#MAGA',
#  'https://t.co/ZVRMGBCE1c',
#  'Join',
#  'me',
#  'on',
#  'Thursday',
#  'afternoon',
#  '(1:00pmE)',
#  'in',
#  'Greenville,',
#  'North',
#  'Carolina',
#  'at',
#  'the',
#  'Pitt-Greenville',
#  'Airport!',
#  '#MAGA',
#  'https://t.co/owg9pSXWJz',
#  'Join',
#  'me',
#  'tomorrow',
#  'tonight',
#  '(Wednesday)',
#  'in',
#  'Iowa,',
#  'at',
#  'the',
#  'Des',
#  'Moines',
#  'International',
#  'Airport!',
#  'https://t.co/92lmaoNdTo',
#  'Join',
#  'me',
#  'tonight',
#  'at',
#  '7:00pmE',
#  'in',
#  'Johnstown,',
#  'Pennsylvania',
#  'at',
#  'the',
#  'John',
#  'Murtha',
#  'Johnstown-Cambria',
#  'County',
#  'Airport!',
#  '#MAGA',
#  'https://t.co/8o9QHHDn1h',
#  '@gmoomaw:',
#  'Virginia’s',
#  'voter',
#  'registration',
#  'system',
#  'reportedly',
#  'having',
#  'problems',
#  'on',
#  'the',
#  'last',
#  'day',
#  'to',
#  'register',
#  'to',
#  'vote,',
#  'with',
#  'early',
#  'voting',
#  'in',
#  'full…',
#  'This',
#  'is',
#  'happening',
#  'all',
#  'over',
#  'the',
#  'U.S.',
#  'Rigged',
#  'Election???',
#  'https://t.co/MG0d9xUH1Z',
#  'STIMULUS!',
#  'Go',
#  'big',
#  'or',
#  'go',
#  'home!!!',
#  '“The',
#  'Radical',
#  'Left',
#  'is',
#  'trying',
#  'hard',
#  'to',
#  'undermine',
#  'the',
#  'Christopher',
#  'Columbus',
#  'legacy.',
#  'A',
#  'great',
#  'Italian',
#  'opened',
#  'new',
#  'chapter',
#  'in',
#  'history',
#  'of',
#  'humanity',
#  'by',
#  'discovering',
#  'the',
#  'Americas”.',
#  '@OANN',
#  'Not',
#  'on',
#  'my',
#  'watch!',
#  'Actually,',
#  'Tony’s',
#  'pitching',
#  'arm',
#  'is',
#  'far',
#  'more',
#  'accurate',
#  'than',
#  'his',
#  'prognostications.',
#  '“No',
#  'problem,',
#  'no',
#  'masks”.',
#  'WHO',
#  'no',
#  'longer',
#  'likes',
#  'Lockdowns',
#  '-',
#  'just',
#  'came',
#  'out',
#  'against.',
#  'Trump',
#  'was',
#  'right.',
#  'We',
#  'saved',
#  '2,000,000',
#  'USA',
#  'lives!!!',
#  'https://t.co/YyLyCsbZ7a',
#  'We',
#  'love',
#  'the',
#  'people',
#  'of',
#  'Lake',
#  'Charles,',
#  'Louisiana.',
#  'You’ve',
#  'been',
#  'hit',
#  'hard',
#  ',',
#  'and',
#  'often,',
#  'but',
#  'your',
#  'Federal',
#  'Government',
#  'is',
#  'there',
#  'to',
#  'help.',
#  'It',
#  'will',
#  'all',
#  'work',
#  'out,',
#  'and',
#  'FAST!!!',
#  '@fema',
#  '@USArmy',
#  'Republicans',
#  'will',
#  'be',
#  'providing',
#  'far',
#  'better',
#  'Healthcare',
#  'than',
#  'the',
#  'Democrats,',
#  'at',
#  'a',
#  'far',
#  'lower',
#  'cost...And',
#  'will',
#  'always',
#  'protect',
#  'people',
#  'with',
#  'Pre-existing',
#  'conditions!!!!',
#  'GOP',
#  'raises',
#  'over',
#  '1',
#  'Billion',
#  'Dollars',
#  'through',
#  '@WINRED',
#  'since',
#  'recent',
#  'founding.',
#  'November',
#  '3rd.',
#  'The',
#  'most',
#  'important',
#  'Election',
#  'in',
#  'the',
#  'History',
#  'of',
#  'our',
#  'Country!!!',
#  'California',
#  'hired',
#  'a',
#  'pure',
#  'Sleepy',
#  'Joe',
#  'Democrat',
#  'firm',
#  'to',
#  'count',
#  'and',
#  '“harvest”',
#  'votes.',
#  'No',
#  'way',
#  'Republicans',
#  'get',
#  'a',
#  'fair',
#  'shake.',
#  'Lawyers,',
#  'get',
#  'started!!!',
#  '@GOPLeader',
#  'California',
#  'is',
#  'in',
#  'big',
#  'trouble.',
#  'Vote',
#  'Trump',
#  'and',
#  'watch',
#  'the',
#  'greatest',
#  'comeback',
#  'of',
#  'them',
#  'all!!!',
#  'Also,',
#  'New',
#  'York',
#  'and',
#  'Illinois',
#  '-',
#  'go',
#  'for',
#  'it!',
#  'Congratulations',
#  'Dan.',
#  'You,',
#  'Breitbart',
#  'and',
#  'others',
#  'have',
#  'decimated',
#  'the',
#  'business',
#  'at',
#  'Drudge.',
#  'It’s',
#  'gone',
#  'the',
#  'way',
#  'of',
#  'the',
#  '@NBA,',
#  'ratings',
#  'down',
#  '70%.',
#  'People',
#  'want',
#  'the',
#  'TRUTH!',
#  'Drudge',
#  'Report',
#  'sold',
#  'out,',
#  'suffered',
#  'a',
#  'massive',
#  '“nervous',
#  'breakdown”.',
#  'Happening',
#  '@FoxNews',
#  'also???',
#  'https://t.co/Zr07XdHtNx',
#  '@seanhannity:',
#  '#HANNITY:',
#  'Biden',
#  'disrespects',
#  'voters',
#  'with',
#  'court-packing',
#  'dodge.',
#  'Exclusive:',
#  '@LawrenceBJones3',
#  'talks',
#  'to',
#  'Trump',
#  'supporters',
#  'in',
#  'FL.…',
#  '@dbongino:',
#  'It’s',
#  'Tuesday,',
#  'October',
#  '13th',
#  '2020,',
#  'and',
#  'Barack',
#  'Obama',
#  'was',
#  'the',
#  'most',
#  'corrupt',
#  'President',
#  'in',
#  'US',
#  'history.',
#  '#Obamagate',
#  '@realDonaldTrump:',
#  'https://t.co/OzYzLQ2FQp',
#  'Thank',
#  'you',
#  'Greg.',
#  'You',
#  'got',
#  'their',
#  'Hoax',
#  'right',
#  'from',
#  'the',
#  'beginning!',
#  'https://t.co/3ql3nADDD9',
#  'Thank',
#  'you,',
#  'so',
#  'nice!',
#  'https://t.co/7GlapStrEB',
#  '@SenateGOP:',
#  "Today's",
#  'the',
#  'day.',
#  '#ConfirmACB',
#  'https://t.co/iNq26Kvona',
#  '@SenJoniErnst:',
#  'Only',
#  '100',
#  'years',
#  'ago,',
#  ...]

# %%
#Removing Punctuation

tweets = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

tweets2 = []

for word in tweets:
    if word != '':
        tweets2.append(word)

# %%
tweets2
# Out:
# ['HerschelWalker',
#  'GEORGIA',
#  'Lets',
#  'go',
#  'VOTE',
#  'to',
#  'keep',
#  'our',
#  'Freedoms',
#  'for',
#  'the',
#  'best',
#  'country',
#  'in',
#  'the',
#  'world',
#  'potus',
#  'MAGA2020',
#  'Trump2020',
#  'KAG2',
#  'realDonaldTrump',
#  'Republicans',
#  'will',
#  'be',
#  'providing',
#  'far',
#  'better',
#  'Healthcare',
#  'than',
#  'the',
#  'Democrats',
#  'at',
#  'a',
#  'far',
#  'lower',
#  'costAnd',
#  'will',
#  'always',
#  'protect',
#  'Georgia',
#  'this',
#  'is',
#  'your',
#  'chance',
#  'to',
#  'MAKE',
#  'AMERICA',
#  'GREAT',
#  'AGAIN',
#  'We',
#  'have',
#  'been',
#  'strong',
#  'for',
#  'our',
#  'Military',
#  'Vets',
#  '2nd',
#  'Amendment',
#  'and',
#  'ALL',
#  'VOTE',
#  'NOW',
#  'Fight',
#  'hard',
#  'Republicans',
#  'They',
#  'have',
#  'been',
#  'taking',
#  'advantage',
#  'of',
#  'the',
#  'system',
#  'for',
#  'years',
#  'httpstcovaToeGjrHG',
#  'httpstcogsFSghkmdM',
#  'GaryCoby',
#  'YES',
#  'Watch',
#  'GamebredFighter',
#  'MAGA',
#  'SuperBowl',
#  'httpstco2bgAdkMFJv',
#  'Great',
#  'night',
#  'in',
#  'Pennsylvania',
#  'Big',
#  'and',
#  'Enthusiastic',
#  'Crowd',
#  'Will',
#  'be',
#  'back',
#  'soon',
#  'VOTE',
#  'Vote',
#  'for',
#  'Trump',
#  'Save',
#  'your',
#  '2nd',
#  'Amendment',
#  'httpstcoQYt5K7oYws',
#  'WAVYNews',
#  'A',
#  'lawsuit',
#  'seeking',
#  'to',
#  'extend',
#  'Virginias',
#  'voter',
#  'registration',
#  'deadline',
#  'was',
#  'filed',
#  'Tuesday',
#  'night',
#  'after',
#  'the',
#  'states',
#  'Department',
#  'of',
#  'E',
#  'Virginia',
#  'VOTE',
#  'for',
#  'President',
#  'Trump',
#  'and',
#  'save',
#  'your',
#  'under',
#  'siege',
#  '2nd',
#  'Amendment',
#  'httpstcoV0AGM7gLaL',
#  'httpstco75J7mUX0Iy',
#  'McguireScotty',
#  'This',
#  'is',
#  'Lee',
#  'Keltner',
#  'He',
#  'is',
#  'the',
#  'victim',
#  'of',
#  'the',
#  'Denver',
#  'shooting',
#  'He',
#  'made',
#  'cowboy',
#  'hats',
#  'Denver',
#  'has',
#  'a',
#  'DemocRat',
#  'mayor',
#  'Pray',
#  'f',
#  'TaylerUSA',
#  'Yesterday',
#  'in',
#  'Denver',
#  'a',
#  'Conservative',
#  'was',
#  'executed',
#  'by',
#  'Matt',
#  'Dolloff',
#  'DenverPolice',
#  'claim',
#  'he',
#  'has',
#  'no',
#  'connections',
#  'to',
#  'ANTIFA',
#  'but',
#  't',
#  'stillgray',
#  'Extended',
#  'sequence',
#  'of',
#  'events',
#  'in',
#  'Denver',
#  'The',
#  'victim',
#  'backed',
#  'off',
#  'He',
#  'never',
#  'stood',
#  'a',
#  'chance',
#  'httpstco4HSSYQ1wrx',
#  'BreitbartNews',
#  'Facebook',
#  'has',
#  'reportedly',
#  'disabled',
#  'the',
#  'account',
#  'of',
#  'former',
#  'US',
#  'Marine',
#  'Corps',
#  'Sergeant',
#  'John',
#  'Tig',
#  'Tiegen',
#  'one',
#  'of',
#  'the',
#  'men',
#  'who',
#  'MrAndyNgo',
#  'Tonight',
#  'the',
#  'indigenous',
#  'faction',
#  'of',
#  'antifa',
#  'held',
#  'a',
#  'day',
#  'of',
#  'rage',
#  'riot',
#  'in',
#  'Portland',
#  'They',
#  'banned',
#  'video',
#  'recording',
#  'as',
#  'the',
#  'crimina',
#  'VFL2013',
#  'Well',
#  'I',
#  'will',
#  'never',
#  'let',
#  'you',
#  'down',
#  'MAGA',
#  'httpstco22qkatrJb2',
#  'Seitzer1',
#  'UFCs',
#  'GamebredFighter',
#  'gives',
#  'one',
#  'of',
#  'the',
#  'best',
#  'vote',
#  'for',
#  'Trump',
#  'speeches',
#  'Ive',
#  'heard',
#  'httpstcoYstONQTYeF',
#  'httpstcowJN4zv0y8O',
#  'For',
#  'years',
#  'you',
#  'had',
#  'a',
#  'President',
#  'who',
#  'apologized',
#  'for',
#  'America',
#  'now',
#  'you',
#  'have',
#  'a',
#  'President',
#  'who',
#  'is',
#  'standing',
#  'up',
#  'for',
#  'America',
#  'and',
#  'standing',
#  'up',
#  'for',
#  'Pennsylvania',
#  'So',
#  'get',
#  'your',
#  'friends',
#  'get',
#  'your',
#  'family',
#  'get',
#  'your',
#  'neighbors',
#  'and',
#  'GET',
#  'OUT',
#  'AND',
#  'VOTE',
#  'httpstcogsFSgh2KPc',
#  'httpstcoxfZtBixRkk',
#  'Proud',
#  'citizens',
#  'like',
#  'you',
#  'helped',
#  'build',
#  'this',
#  'Countryand',
#  'together',
#  'we',
#  'are',
#  'taking',
#  'back',
#  'our',
#  'Country',
#  'We',
#  'are',
#  'returning',
#  'power',
#  'to',
#  'YOU',
#  'the',
#  'American',
#  'People',
#  'MAGA',
#  'httpstcorn69eJJAPV',
#  'This',
#  'election',
#  'is',
#  'a',
#  'simple',
#  'choice',
#  'If',
#  'Biden',
#  'Wins',
#  'China',
#  'Wins',
#  'When',
#  'WE',
#  'Win',
#  'YOU',
#  'WIN',
#  'Pennsylvania',
#  'WINS',
#  'and',
#  'America',
#  'WINS',
#  'httpstcodgx92ZxsBO',
#  'One',
#  'of',
#  'the',
#  'most',
#  'important',
#  'issues',
#  'for',
#  'Pennsylvania',
#  'is',
#  'the',
#  'survival',
#  'of',
#  'your',
#  'fracking',
#  'industry',
#  'Joe',
#  'Biden',
#  'has',
#  'repeatedly',
#  'pledged',
#  'to',
#  'abolish',
#  'fracking',
#  'When',
#  'asked',
#  'about',
#  'fracking',
#  'Biden',
#  'said',
#  'he',
#  'would',
#  'make',
#  'sure',
#  'its',
#  'ELIMINATED',
#  'With',
#  'me',
#  'youre',
#  'going',
#  'to',
#  'FRACK',
#  'httpstcotHt7Chh4jB',
#  'Thank',
#  'you',
#  'Johnstown',
#  'Pennsylvania',
#  'httpstcomdHfNODJCT',
#  'You',
#  'mean',
#  'only',
#  'Democrats',
#  'are',
#  'allowed',
#  'to',
#  'do',
#  'this',
#  'But',
#  'havent',
#  'the',
#  'Dems',
#  'been',
#  'doing',
#  'this',
#  'for',
#  'years',
#  'See',
#  'you',
#  'in',
#  'court',
#  'Fight',
#  'hard',
#  'Republicans',
#  'httpstcovaToeGB2ze',
#  'Watch',
#  'OANN',
#  'newsmax',
#  'cspan',
#  'Just',
#  'arrived',
#  'in',
#  'Pennsylvania',
#  'Enjoy',
#  'Getting',
#  'ready',
#  'to',
#  'land',
#  'in',
#  'Johnstown',
#  'Pennsylvania',
#  'Big',
#  'crowd',
#  'See',
#  'you',
#  'soon',
#  'Totally',
#  'Negative',
#  'China',
#  'Virus',
#  'Reports',
#  'Hit',
#  'it',
#  'early',
#  'and',
#  'hard',
#  'Fake',
#  'News',
#  'is',
#  'devastated',
#  'They',
#  'are',
#  'very',
#  'bad',
#  'and',
#  'sick',
#  'people',
#  'protecting',
#  'people',
#  'with',
#  'Preexisting',
#  'conditions',
#  'He',
#  'has',
#  'done',
#  'nothing',
#  'on',
#  'Healthcare',
#  'cost',
#  'or',
#  'otherwise',
#  'or',
#  'virtually',
#  'anything',
#  'else',
#  'An',
#  'empty',
#  'suit',
#  'How',
#  'dare',
#  'failed',
#  'Presidential',
#  'Candidate',
#  '1',
#  'and',
#  'falling',
#  'CoryBooker',
#  'make',
#  'false',
#  'charges',
#  'and',
#  'statements',
#  'about',
#  'me',
#  'in',
#  'addressing',
#  'Judge',
#  'Barrett',
#  'Illegally',
#  'never',
#  'even',
#  'lived',
#  'in',
#  'Newark',
#  'when',
#  'he',
#  'was',
#  'Mayor',
#  'Guy',
#  'is',
#  'a',
#  'total',
#  'loser',
#  'I',
#  'want',
#  'better',
#  'Healthcare',
#  'for',
#  'far',
#  'less',
#  'money',
#  'always',
#  'Early',
#  'voting',
#  'is',
#  'underway',
#  'in',
#  'the',
#  'Great',
#  'States',
#  'of',
#  'GEORGIA',
#  'and',
#  'TEXAS',
#  'Find',
#  'out',
#  'where',
#  'to',
#  'early',
#  'vote',
#  'by',
#  'clicking',
#  'below',
#  'MAGA',
#  'httpstcogsFSghkmdM',
#  'Happy',
#  '245th',
#  'Birthday',
#  'to',
#  'our',
#  'GREAT',
#  'USNavy',
#  'Navy245',
#  'httpstcoEEGIwCh0wD',
#  'Volunteer',
#  'to',
#  'be',
#  'a',
#  'Trump',
#  'Election',
#  'Poll',
#  'Watcher',
#  'Sign',
#  'up',
#  'today',
#  'MakeAmericaGreatAgain',
#  'httpstco3AnrRV7uSz',
#  'Join',
#  'me',
#  'Friday',
#  '1016',
#  'evening',
#  'at',
#  '700pmE',
#  'in',
#  'Macon',
#  'Georgia',
#  'at',
#  'the',
#  'Middle',
#  'Georgia',
#  'Regional',
#  'Airport',
#  'MAGA',
#  'httpstcorZbqKTueVg',
#  'Join',
#  'me',
#  'Friday',
#  '1016',
#  'in',
#  'Ocala',
#  'Florida',
#  'at',
#  'the',
#  'Ocala',
#  'International',
#  'Airport',
#  'at',
#  '400pmE',
#  'MAGA',
#  'httpstcoZVRMGBCE1c',
#  'Join',
#  'me',
#  'on',
#  'Thursday',
#  'afternoon',
#  '100pmE',
#  'in',
#  'Greenville',
#  'North',
#  'Carolina',
#  'at',
#  'the',
#  'PittGreenville',
#  'Airport',
#  'MAGA',
#  'httpstcoowg9pSXWJz',
#  'Join',
#  'me',
#  'tomorrow',
#  'tonight',
#  'Wednesday',
#  'in',
#  'Iowa',
#  'at',
#  'the',
#  'Des',
#  'Moines',
#  'International',
#  'Airport',
#  'httpstco92lmaoNdTo',
#  'Join',
#  'me',
#  'tonight',
#  'at',
#  '700pmE',
#  'in',
#  'Johnstown',
#  'Pennsylvania',
#  'at',
#  'the',
#  'John',
#  'Murtha',
#  'JohnstownCambria',
#  'County',
#  'Airport',
#  'MAGA',
#  'httpstco8o9QHHDn1h',
#  'gmoomaw',
#  'Virginias',
#  'voter',
#  'registration',
#  'system',
#  'reportedly',
#  'having',
#  'problems',
#  'on',
#  'the',
#  'last',
#  'day',
#  'to',
#  'register',
#  'to',
#  'vote',
#  'with',
#  'early',
#  'voting',
#  'in',
#  'full',
#  'This',
#  'is',
#  'happening',
#  'all',
#  'over',
#  'the',
#  'US',
#  'Rigged',
#  'Election',
#  'httpstcoMG0d9xUH1Z',
#  'STIMULUS',
#  'Go',
#  'big',
#  'or',
#  'go',
#  'home',
#  'The',
#  'Radical',
#  'Left',
#  'is',
#  'trying',
#  'hard',
#  'to',
#  'undermine',
#  'the',
#  'Christopher',
#  'Columbus',
#  'legacy',
#  'A',
#  'great',
#  'Italian',
#  'opened',
#  'new',
#  'chapter',
#  'in',
#  'history',
#  'of',
#  'humanity',
#  'by',
#  'discovering',
#  'the',
#  'Americas',
#  'OANN',
#  'Not',
#  'on',
#  'my',
#  'watch',
#  'Actually',
#  'Tonys',
#  'pitching',
#  'arm',
#  'is',
#  'far',
#  'more',
#  'accurate',
#  'than',
#  'his',
#  'prognostications',
#  'No',
#  'problem',
#  'no',
#  'masks',
#  'WHO',
#  'no',
#  'longer',
#  'likes',
#  'Lockdowns',
#  'just',
#  'came',
#  'out',
#  'against',
#  'Trump',
#  'was',
#  'right',
#  'We',
#  'saved',
#  '2000000',
#  'USA',
#  'lives',
#  'httpstcoYyLyCsbZ7a',
#  'We',
#  'love',
#  'the',
#  'people',
#  'of',
#  'Lake',
#  'Charles',
#  'Louisiana',
#  'Youve',
#  'been',
#  'hit',
#  'hard',
#  'and',
#  'often',
#  'but',
#  'your',
#  'Federal',
#  'Government',
#  'is',
#  'there',
#  'to',
#  'help',
#  'It',
#  'will',
#  'all',
#  'work',
#  'out',
#  'and',
#  'FAST',
#  'fema',
#  'USArmy',
#  'Republicans',
#  'will',
#  'be',
#  'providing',
#  'far',
#  'better',
#  'Healthcare',
#  'than',
#  'the',
#  'Democrats',
#  'at',
#  'a',
#  'far',
#  'lower',
#  'costAnd',
#  'will',
#  'always',
#  'protect',
#  'people',
#  'with',
#  'Preexisting',
#  'conditions',
#  'GOP',
#  'raises',
#  'over',
#  '1',
#  'Billion',
#  'Dollars',
#  'through',
#  'WINRED',
#  'since',
#  'recent',
#  'founding',
#  'November',
#  '3rd',
#  'The',
#  'most',
#  'important',
#  'Election',
#  'in',
#  'the',
#  'History',
#  'of',
#  'our',
#  'Country',
#  'California',
#  'hired',
#  'a',
#  'pure',
#  'Sleepy',
#  'Joe',
#  'Democrat',
#  'firm',
#  'to',
#  'count',
#  'and',
#  'harvest',
#  'votes',
#  'No',
#  'way',
#  'Republicans',
#  'get',
#  'a',
#  'fair',
#  'shake',
#  'Lawyers',
#  'get',
#  'started',
#  'GOPLeader',
#  'California',
#  'is',
#  'in',
#  'big',
#  'trouble',
#  'Vote',
#  'Trump',
#  'and',
#  'watch',
#  'the',
#  'greatest',
#  'comeback',
#  'of',
#  'them',
#  'all',
#  'Also',
#  'New',
#  'York',
#  'and',
#  'Illinois',
#  'go',
#  'for',
#  'it',
#  'Congratulations',
#  'Dan',
#  'You',
#  'Breitbart',
#  'and',
#  'others',
#  'have',
#  'decimated',
#  'the',
#  'business',
#  'at',
#  'Drudge',
#  'Its',
#  'gone',
#  'the',
#  'way',
#  'of',
#  'the',
#  'NBA',
#  'ratings',
#  'down',
#  '70',
#  'People',
#  'want',
#  'the',
#  'TRUTH',
#  'Drudge',
#  'Report',
#  'sold',
#  'out',
#  'suffered',
#  'a',
#  'massive',
#  'nervous',
#  'breakdown',
#  'Happening',
#  'FoxNews',
#  'also',
#  'httpstcoZr07XdHtNx',
#  'seanhannity',
#  'HANNITY',
#  'Biden',
#  'disrespects',
#  'voters',
#  'with',
#  'courtpacking',
#  'dodge',
#  'Exclusive',
#  'LawrenceBJones3',
#  'talks',
#  'to',
#  'Trump',
#  'supporters',
#  'in',
#  'FL',
#  'dbongino',
#  'Its',
#  'Tuesday',
#  'October',
#  '13th',
#  '2020',
#  'and',
#  'Barack',
#  'Obama',
#  'was',
#  'the',
#  'most',
#  'corrupt',
#  'President',
#  'in',
#  'US',
#  'history',
#  'Obamagate',
#  'realDonaldTrump',
#  'httpstcoOzYzLQ2FQp',
#  'Thank',
#  'you',
#  'Greg',
#  'You',
#  'got',
#  'their',
#  'Hoax',
#  'right',
#  'from',
#  'the',
#  'beginning',
#  'httpstco3ql3nADDD9',
#  'Thank',
#  'you',
#  'so',
#  'nice',
#  'httpstco7GlapStrEB',
#  'SenateGOP',
#  'Todays',
#  'the',
#  'day',
#  'ConfirmACB',
#  'httpstcoiNq26Kvona',
#  'SenJoniErnst',
#  'Only',
#  '100',
#  'years',
#  'ago',
#  'women',
#  'in',
#  'this',
#  'country',
#  'were',
#  ...]

# %%
#This is stemming the words to their root
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

stem = []
for word in tweets2:
    stem.append(s_stemmer.stem(word))
    
stem
# Out:
# ['herschelwalk',
#  'georgia',
#  'let',
#  'go',
#  'vote',
#  'to',
#  'keep',
#  'our',
#  'freedom',
#  'for',
#  'the',
#  'best',
#  'countri',
#  'in',
#  'the',
#  'world',
#  'potus',
#  'maga2020',
#  'trump2020',
#  'kag2',
#  'realdonaldtrump',
#  'republican',
#  'will',
#  'be',
#  'provid',
#  'far',
#  'better',
#  'healthcar',
#  'than',
#  'the',
#  'democrat',
#  'at',
#  'a',
#  'far',
#  'lower',
#  'costand',
#  'will',
#  'alway',
#  'protect',
#  'georgia',
#  'this',
#  'is',
#  'your',
#  'chanc',
#  'to',
#  'make',
#  'america',
#  'great',
#  'again',
#  'we',
#  'have',
#  'been',
#  'strong',
#  'for',
#  'our',
#  'militari',
#  'vet',
#  '2nd',
#  'amend',
#  'and',
#  'all',
#  'vote',
#  'now',
#  'fight',
#  'hard',
#  'republican',
#  'they',
#  'have',
#  'been',
#  'take',
#  'advantag',
#  'of',
#  'the',
#  'system',
#  'for',
#  'year',
#  'httpstcovatoegjrhg',
#  'httpstcogsfsghkmdm',
#  'garycobi',
#  'yes',
#  'watch',
#  'gamebredfight',
#  'maga',
#  'superbowl',
#  'httpstco2bgadkmfjv',
#  'great',
#  'night',
#  'in',
#  'pennsylvania',
#  'big',
#  'and',
#  'enthusiast',
#  'crowd',
#  'will',
#  'be',
#  'back',
#  'soon',
#  'vote',
#  'vote',
#  'for',
#  'trump',
#  'save',
#  'your',
#  '2nd',
#  'amend',
#  'httpstcoqyt5k7oyw',
#  'wavynew',
#  'a',
#  'lawsuit',
#  'seek',
#  'to',
#  'extend',
#  'virginia',
#  'voter',
#  'registr',
#  'deadlin',
#  'was',
#  'file',
#  'tuesday',
#  'night',
#  'after',
#  'the',
#  'state',
#  'depart',
#  'of',
#  'e',
#  'virginia',
#  'vote',
#  'for',
#  'presid',
#  'trump',
#  'and',
#  'save',
#  'your',
#  'under',
#  'sieg',
#  '2nd',
#  'amend',
#  'httpstcov0agm7gl',
#  'httpstco75j7mux0iy',
#  'mcguirescotti',
#  'this',
#  'is',
#  'lee',
#  'keltner',
#  'he',
#  'is',
#  'the',
#  'victim',
#  'of',
#  'the',
#  'denver',
#  'shoot',
#  'he',
#  'made',
#  'cowboy',
#  'hat',
#  'denver',
#  'has',
#  'a',
#  'democrat',
#  'mayor',
#  'pray',
#  'f',
#  'taylerusa',
#  'yesterday',
#  'in',
#  'denver',
#  'a',
#  'conserv',
#  'was',
#  'execut',
#  'by',
#  'matt',
#  'dolloff',
#  'denverpolic',
#  'claim',
#  'he',
#  'has',
#  'no',
#  'connect',
#  'to',
#  'antifa',
#  'but',
#  't',
#  'stillgray',
#  'extend',
#  'sequenc',
#  'of',
#  'event',
#  'in',
#  'denver',
#  'the',
#  'victim',
#  'back',
#  'off',
#  'he',
#  'never',
#  'stood',
#  'a',
#  'chanc',
#  'httpstco4hssyq1wrx',
#  'breitbartnew',
#  'facebook',
#  'has',
#  'report',
#  'disabl',
#  'the',
#  'account',
#  'of',
#  'former',
#  'us',
#  'marin',
#  'corp',
#  'sergeant',
#  'john',
#  'tig',
#  'tiegen',
#  'one',
#  'of',
#  'the',
#  'men',
#  'who',
#  'mrandyngo',
#  'tonight',
#  'the',
#  'indigen',
#  'faction',
#  'of',
#  'antifa',
#  'held',
#  'a',
#  'day',
#  'of',
#  'rage',
#  'riot',
#  'in',
#  'portland',
#  'they',
#  'ban',
#  'video',
#  'record',
#  'as',
#  'the',
#  'crimina',
#  'vfl2013',
#  'well',
#  'i',
#  'will',
#  'never',
#  'let',
#  'you',
#  'down',
#  'maga',
#  'httpstco22qkatrjb2',
#  'seitzer1',
#  'ufc',
#  'gamebredfight',
#  'give',
#  'one',
#  'of',
#  'the',
#  'best',
#  'vote',
#  'for',
#  'trump',
#  'speech',
#  'ive',
#  'heard',
#  'httpstcoystonqtyef',
#  'httpstcowjn4zv0y8o',
#  'for',
#  'year',
#  'you',
#  'had',
#  'a',
#  'presid',
#  'who',
#  'apolog',
#  'for',
#  'america',
#  'now',
#  'you',
#  'have',
#  'a',
#  'presid',
#  'who',
#  'is',
#  'stand',
#  'up',
#  'for',
#  'america',
#  'and',
#  'stand',
#  'up',
#  'for',
#  'pennsylvania',
#  'so',
#  'get',
#  'your',
#  'friend',
#  'get',
#  'your',
#  'famili',
#  'get',
#  'your',
#  'neighbor',
#  'and',
#  'get',
#  'out',
#  'and',
#  'vote',
#  'httpstcogsfsgh2kpc',
#  'httpstcoxfztbixrkk',
#  'proud',
#  'citizen',
#  'like',
#  'you',
#  'help',
#  'build',
#  'this',
#  'countryand',
#  'togeth',
#  'we',
#  'are',
#  'take',
#  'back',
#  'our',
#  'countri',
#  'we',
#  'are',
#  'return',
#  'power',
#  'to',
#  'you',
#  'the',
#  'american',
#  'peopl',
#  'maga',
#  'httpstcorn69ejjapv',
#  'this',
#  'elect',
#  'is',
#  'a',
#  'simpl',
#  'choic',
#  'if',
#  'biden',
#  'win',
#  'china',
#  'win',
#  'when',
#  'we',
#  'win',
#  'you',
#  'win',
#  'pennsylvania',
#  'win',
#  'and',
#  'america',
#  'win',
#  'httpstcodgx92zxsbo',
#  'one',
#  'of',
#  'the',
#  'most',
#  'import',
#  'issu',
#  'for',
#  'pennsylvania',
#  'is',
#  'the',
#  'surviv',
#  'of',
#  'your',
#  'frack',
#  'industri',
#  'joe',
#  'biden',
#  'has',
#  'repeat',
#  'pledg',
#  'to',
#  'abolish',
#  'frack',
#  'when',
#  'ask',
#  'about',
#  'frack',
#  'biden',
#  'said',
#  'he',
#  'would',
#  'make',
#  'sure',
#  'it',
#  'elimin',
#  'with',
#  'me',
#  'your',
#  'go',
#  'to',
#  'frack',
#  'httpstcotht7chh4jb',
#  'thank',
#  'you',
#  'johnstown',
#  'pennsylvania',
#  'httpstcomdhfnodjct',
#  'you',
#  'mean',
#  'onli',
#  'democrat',
#  'are',
#  'allow',
#  'to',
#  'do',
#  'this',
#  'but',
#  'havent',
#  'the',
#  'dem',
#  'been',
#  'do',
#  'this',
#  'for',
#  'year',
#  'see',
#  'you',
#  'in',
#  'court',
#  'fight',
#  'hard',
#  'republican',
#  'httpstcovatoegb2z',
#  'watch',
#  'oann',
#  'newsmax',
#  'cspan',
#  'just',
#  'arriv',
#  'in',
#  'pennsylvania',
#  'enjoy',
#  'get',
#  'readi',
#  'to',
#  'land',
#  'in',
#  'johnstown',
#  'pennsylvania',
#  'big',
#  'crowd',
#  'see',
#  'you',
#  'soon',
#  'total',
#  'negat',
#  'china',
#  'virus',
#  'report',
#  'hit',
#  'it',
#  'earli',
#  'and',
#  'hard',
#  'fake',
#  'news',
#  'is',
#  'devast',
#  'they',
#  'are',
#  'veri',
#  'bad',
#  'and',
#  'sick',
#  'peopl',
#  'protect',
#  'peopl',
#  'with',
#  'preexist',
#  'condit',
#  'he',
#  'has',
#  'done',
#  'noth',
#  'on',
#  'healthcar',
#  'cost',
#  'or',
#  'otherwis',
#  'or',
#  'virtual',
#  'anyth',
#  'els',
#  'an',
#  'empti',
#  'suit',
#  'how',
#  'dare',
#  'fail',
#  'presidenti',
#  'candid',
#  '1',
#  'and',
#  'fall',
#  'corybook',
#  'make',
#  'fals',
#  'charg',
#  'and',
#  'statement',
#  'about',
#  'me',
#  'in',
#  'address',
#  'judg',
#  'barrett',
#  'illeg',
#  'never',
#  'even',
#  'live',
#  'in',
#  'newark',
#  'when',
#  'he',
#  'was',
#  'mayor',
#  'guy',
#  'is',
#  'a',
#  'total',
#  'loser',
#  'i',
#  'want',
#  'better',
#  'healthcar',
#  'for',
#  'far',
#  'less',
#  'money',
#  'alway',
#  'earli',
#  'vote',
#  'is',
#  'underway',
#  'in',
#  'the',
#  'great',
#  'state',
#  'of',
#  'georgia',
#  'and',
#  'texa',
#  'find',
#  'out',
#  'where',
#  'to',
#  'earli',
#  'vote',
#  'by',
#  'click',
#  'below',
#  'maga',
#  'httpstcogsfsghkmdm',
#  'happi',
#  '245th',
#  'birthday',
#  'to',
#  'our',
#  'great',
#  'usnavi',
#  'navy245',
#  'httpstcoeegiwch0wd',
#  'volunt',
#  'to',
#  'be',
#  'a',
#  'trump',
#  'elect',
#  'poll',
#  'watcher',
#  'sign',
#  'up',
#  'today',
#  'makeamericagreatagain',
#  'httpstco3anrrv7usz',
#  'join',
#  'me',
#  'friday',
#  '1016',
#  'even',
#  'at',
#  '700pme',
#  'in',
#  'macon',
#  'georgia',
#  'at',
#  'the',
#  'middl',
#  'georgia',
#  'region',
#  'airport',
#  'maga',
#  'httpstcorzbqktuevg',
#  'join',
#  'me',
#  'friday',
#  '1016',
#  'in',
#  'ocala',
#  'florida',
#  'at',
#  'the',
#  'ocala',
#  'intern',
#  'airport',
#  'at',
#  '400pme',
#  'maga',
#  'httpstcozvrmgbce1c',
#  'join',
#  'me',
#  'on',
#  'thursday',
#  'afternoon',
#  '100pme',
#  'in',
#  'greenvill',
#  'north',
#  'carolina',
#  'at',
#  'the',
#  'pittgreenvill',
#  'airport',
#  'maga',
#  'httpstcoowg9psxwjz',
#  'join',
#  'me',
#  'tomorrow',
#  'tonight',
#  'wednesday',
#  'in',
#  'iowa',
#  'at',
#  'the',
#  'des',
#  'moin',
#  'intern',
#  'airport',
#  'httpstco92lmaondto',
#  'join',
#  'me',
#  'tonight',
#  'at',
#  '700pme',
#  'in',
#  'johnstown',
#  'pennsylvania',
#  'at',
#  'the',
#  'john',
#  'murtha',
#  'johnstowncambria',
#  'counti',
#  'airport',
#  'maga',
#  'httpstco8o9qhhdn1h',
#  'gmoomaw',
#  'virginia',
#  'voter',
#  'registr',
#  'system',
#  'report',
#  'have',
#  'problem',
#  'on',
#  'the',
#  'last',
#  'day',
#  'to',
#  'regist',
#  'to',
#  'vote',
#  'with',
#  'earli',
#  'vote',
#  'in',
#  'full',
#  'this',
#  'is',
#  'happen',
#  'all',
#  'over',
#  'the',
#  'us',
#  'rig',
#  'elect',
#  'httpstcomg0d9xuh1z',
#  'stimulus',
#  'go',
#  'big',
#  'or',
#  'go',
#  'home',
#  'the',
#  'radic',
#  'left',
#  'is',
#  'tri',
#  'hard',
#  'to',
#  'undermin',
#  'the',
#  'christoph',
#  'columbus',
#  'legaci',
#  'a',
#  'great',
#  'italian',
#  'open',
#  'new',
#  'chapter',
#  'in',
#  'histori',
#  'of',
#  'human',
#  'by',
#  'discov',
#  'the',
#  'america',
#  'oann',
#  'not',
#  'on',
#  'my',
#  'watch',
#  'actual',
#  'toni',
#  'pitch',
#  'arm',
#  'is',
#  'far',
#  'more',
#  'accur',
#  'than',
#  'his',
#  'prognost',
#  'no',
#  'problem',
#  'no',
#  'mask',
#  'who',
#  'no',
#  'longer',
#  'like',
#  'lockdown',
#  'just',
#  'came',
#  'out',
#  'against',
#  'trump',
#  'was',
#  'right',
#  'we',
#  'save',
#  '2000000',
#  'usa',
#  'live',
#  'httpstcoyylycsbz7a',
#  'we',
#  'love',
#  'the',
#  'peopl',
#  'of',
#  'lake',
#  'charl',
#  'louisiana',
#  'youv',
#  'been',
#  'hit',
#  'hard',
#  'and',
#  'often',
#  'but',
#  'your',
#  'feder',
#  'govern',
#  'is',
#  'there',
#  'to',
#  'help',
#  'it',
#  'will',
#  'all',
#  'work',
#  'out',
#  'and',
#  'fast',
#  'fema',
#  'usarmi',
#  'republican',
#  'will',
#  'be',
#  'provid',
#  'far',
#  'better',
#  'healthcar',
#  'than',
#  'the',
#  'democrat',
#  'at',
#  'a',
#  'far',
#  'lower',
#  'costand',
#  'will',
#  'alway',
#  'protect',
#  'peopl',
#  'with',
#  'preexist',
#  'condit',
#  'gop',
#  'rais',
#  'over',
#  '1',
#  'billion',
#  'dollar',
#  'through',
#  'winr',
#  'sinc',
#  'recent',
#  'found',
#  'novemb',
#  '3rd',
#  'the',
#  'most',
#  'import',
#  'elect',
#  'in',
#  'the',
#  'histori',
#  'of',
#  'our',
#  'countri',
#  'california',
#  'hire',
#  'a',
#  'pure',
#  'sleepi',
#  'joe',
#  'democrat',
#  'firm',
#  'to',
#  'count',
#  'and',
#  'harvest',
#  'vote',
#  'no',
#  'way',
#  'republican',
#  'get',
#  'a',
#  'fair',
#  'shake',
#  'lawyer',
#  'get',
#  'start',
#  'goplead',
#  'california',
#  'is',
#  'in',
#  'big',
#  'troubl',
#  'vote',
#  'trump',
#  'and',
#  'watch',
#  'the',
#  'greatest',
#  'comeback',
#  'of',
#  'them',
#  'all',
#  'also',
#  'new',
#  'york',
#  'and',
#  'illinoi',
#  'go',
#  'for',
#  'it',
#  'congratul',
#  'dan',
#  'you',
#  'breitbart',
#  'and',
#  'other',
#  'have',
#  'decim',
#  'the',
#  'busi',
#  'at',
#  'drudg',
#  'it',
#  'gone',
#  'the',
#  'way',
#  'of',
#  'the',
#  'nba',
#  'rate',
#  'down',
#  '70',
#  'peopl',
#  'want',
#  'the',
#  'truth',
#  'drudg',
#  'report',
#  'sold',
#  'out',
#  'suffer',
#  'a',
#  'massiv',
#  'nervous',
#  'breakdown',
#  'happen',
#  'foxnew',
#  'also',
#  'httpstcozr07xdhtnx',
#  'seanhann',
#  'hanniti',
#  'biden',
#  'disrespect',
#  'voter',
#  'with',
#  'courtpack',
#  'dodg',
#  'exclus',
#  'lawrencebjones3',
#  'talk',
#  'to',
#  'trump',
#  'support',
#  'in',
#  'fl',
#  'dbongino',
#  'it',
#  'tuesday',
#  'octob',
#  '13th',
#  '2020',
#  'and',
#  'barack',
#  'obama',
#  'was',
#  'the',
#  'most',
#  'corrupt',
#  'presid',
#  'in',
#  'us',
#  'histori',
#  'obamag',
#  'realdonaldtrump',
#  'httpstcoozyzlq2fqp',
#  'thank',
#  'you',
#  'greg',
#  'you',
#  'got',
#  'their',
#  'hoax',
#  'right',
#  'from',
#  'the',
#  'begin',
#  'httpstco3ql3naddd9',
#  'thank',
#  'you',
#  'so',
#  'nice',
#  'httpstco7glapstreb',
#  'senategop',
#  'today',
#  'the',
#  'day',
#  'confirmacb',
#  'httpstcoinq26kvona',
#  'senjoniernst',
#  'onli',
#  '100',
#  'year',
#  'ago',
#  'women',
#  'in',
#  'this',
#  'countri',
#  'were',
#  ...]

# %%
len(stem)
# Out:
# 37206

# %%
#Removing all Stop Words

#Import the english stop words list from NLTK
stopwords_english = stopwords.words('english') 

stem2 = []

for word in stem:
    if (word not in stopwords_english and  # remove stopwords
        word not in string.punctuation):  # remove punctuation
        stem2.append(word)

stem2
# Out:
# ['herschelwalk',
#  'georgia',
#  'let',
#  'go',
#  'vote',
#  'keep',
#  'freedom',
#  'best',
#  'countri',
#  'world',
#  'potus',
#  'maga2020',
#  'trump2020',
#  'kag2',
#  'realdonaldtrump',
#  'republican',
#  'provid',
#  'far',
#  'better',
#  'healthcar',
#  'democrat',
#  'far',
#  'lower',
#  'costand',
#  'alway',
#  'protect',
#  'georgia',
#  'chanc',
#  'make',
#  'america',
#  'great',
#  'strong',
#  'militari',
#  'vet',
#  '2nd',
#  'amend',
#  'vote',
#  'fight',
#  'hard',
#  'republican',
#  'take',
#  'advantag',
#  'system',
#  'year',
#  'httpstcovatoegjrhg',
#  'httpstcogsfsghkmdm',
#  'garycobi',
#  'yes',
#  'watch',
#  'gamebredfight',
#  'maga',
#  'superbowl',
#  'httpstco2bgadkmfjv',
#  'great',
#  'night',
#  'pennsylvania',
#  'big',
#  'enthusiast',
#  'crowd',
#  'back',
#  'soon',
#  'vote',
#  'vote',
#  'trump',
#  'save',
#  '2nd',
#  'amend',
#  'httpstcoqyt5k7oyw',
#  'wavynew',
#  'lawsuit',
#  'seek',
#  'extend',
#  'virginia',
#  'voter',
#  'registr',
#  'deadlin',
#  'file',
#  'tuesday',
#  'night',
#  'state',
#  'depart',
#  'e',
#  'virginia',
#  'vote',
#  'presid',
#  'trump',
#  'save',
#  'sieg',
#  '2nd',
#  'amend',
#  'httpstcov0agm7gl',
#  'httpstco75j7mux0iy',
#  'mcguirescotti',
#  'lee',
#  'keltner',
#  'victim',
#  'denver',
#  'shoot',
#  'made',
#  'cowboy',
#  'hat',
#  'denver',
#  'democrat',
#  'mayor',
#  'pray',
#  'f',
#  'taylerusa',
#  'yesterday',
#  'denver',
#  'conserv',
#  'execut',
#  'matt',
#  'dolloff',
#  'denverpolic',
#  'claim',
#  'connect',
#  'antifa',
#  'stillgray',
#  'extend',
#  'sequenc',
#  'event',
#  'denver',
#  'victim',
#  'back',
#  'never',
#  'stood',
#  'chanc',
#  'httpstco4hssyq1wrx',
#  'breitbartnew',
#  'facebook',
#  'report',
#  'disabl',
#  'account',
#  'former',
#  'us',
#  'marin',
#  'corp',
#  'sergeant',
#  'john',
#  'tig',
#  'tiegen',
#  'one',
#  'men',
#  'mrandyngo',
#  'tonight',
#  'indigen',
#  'faction',
#  'antifa',
#  'held',
#  'day',
#  'rage',
#  'riot',
#  'portland',
#  'ban',
#  'video',
#  'record',
#  'crimina',
#  'vfl2013',
#  'well',
#  'never',
#  'let',
#  'maga',
#  'httpstco22qkatrjb2',
#  'seitzer1',
#  'ufc',
#  'gamebredfight',
#  'give',
#  'one',
#  'best',
#  'vote',
#  'trump',
#  'speech',
#  'ive',
#  'heard',
#  'httpstcoystonqtyef',
#  'httpstcowjn4zv0y8o',
#  'year',
#  'presid',
#  'apolog',
#  'america',
#  'presid',
#  'stand',
#  'america',
#  'stand',
#  'pennsylvania',
#  'get',
#  'friend',
#  'get',
#  'famili',
#  'get',
#  'neighbor',
#  'get',
#  'vote',
#  'httpstcogsfsgh2kpc',
#  'httpstcoxfztbixrkk',
#  'proud',
#  'citizen',
#  'like',
#  'help',
#  'build',
#  'countryand',
#  'togeth',
#  'take',
#  'back',
#  'countri',
#  'return',
#  'power',
#  'american',
#  'peopl',
#  'maga',
#  'httpstcorn69ejjapv',
#  'elect',
#  'simpl',
#  'choic',
#  'biden',
#  'win',
#  'china',
#  'win',
#  'win',
#  'win',
#  'pennsylvania',
#  'win',
#  'america',
#  'win',
#  'httpstcodgx92zxsbo',
#  'one',
#  'import',
#  'issu',
#  'pennsylvania',
#  'surviv',
#  'frack',
#  'industri',
#  'joe',
#  'biden',
#  'repeat',
#  'pledg',
#  'abolish',
#  'frack',
#  'ask',
#  'frack',
#  'biden',
#  'said',
#  'would',
#  'make',
#  'sure',
#  'elimin',
#  'go',
#  'frack',
#  'httpstcotht7chh4jb',
#  'thank',
#  'johnstown',
#  'pennsylvania',
#  'httpstcomdhfnodjct',
#  'mean',
#  'onli',
#  'democrat',
#  'allow',
#  'havent',
#  'dem',
#  'year',
#  'see',
#  'court',
#  'fight',
#  'hard',
#  'republican',
#  'httpstcovatoegb2z',
#  'watch',
#  'oann',
#  'newsmax',
#  'cspan',
#  'arriv',
#  'pennsylvania',
#  'enjoy',
#  'get',
#  'readi',
#  'land',
#  'johnstown',
#  'pennsylvania',
#  'big',
#  'crowd',
#  'see',
#  'soon',
#  'total',
#  'negat',
#  'china',
#  'virus',
#  'report',
#  'hit',
#  'earli',
#  'hard',
#  'fake',
#  'news',
#  'devast',
#  'veri',
#  'bad',
#  'sick',
#  'peopl',
#  'protect',
#  'peopl',
#  'preexist',
#  'condit',
#  'done',
#  'noth',
#  'healthcar',
#  'cost',
#  'otherwis',
#  'virtual',
#  'anyth',
#  'els',
#  'empti',
#  'suit',
#  'dare',
#  'fail',
#  'presidenti',
#  'candid',
#  '1',
#  'fall',
#  'corybook',
#  'make',
#  'fals',
#  'charg',
#  'statement',
#  'address',
#  'judg',
#  'barrett',
#  'illeg',
#  'never',
#  'even',
#  'live',
#  'newark',
#  'mayor',
#  'guy',
#  'total',
#  'loser',
#  'want',
#  'better',
#  'healthcar',
#  'far',
#  'less',
#  'money',
#  'alway',
#  'earli',
#  'vote',
#  'underway',
#  'great',
#  'state',
#  'georgia',
#  'texa',
#  'find',
#  'earli',
#  'vote',
#  'click',
#  'maga',
#  'httpstcogsfsghkmdm',
#  'happi',
#  '245th',
#  'birthday',
#  'great',
#  'usnavi',
#  'navy245',
#  'httpstcoeegiwch0wd',
#  'volunt',
#  'trump',
#  'elect',
#  'poll',
#  'watcher',
#  'sign',
#  'today',
#  'makeamericagreatagain',
#  'httpstco3anrrv7usz',
#  'join',
#  'friday',
#  '1016',
#  'even',
#  '700pme',
#  'macon',
#  'georgia',
#  'middl',
#  'georgia',
#  'region',
#  'airport',
#  'maga',
#  'httpstcorzbqktuevg',
#  'join',
#  'friday',
#  '1016',
#  'ocala',
#  'florida',
#  'ocala',
#  'intern',
#  'airport',
#  '400pme',
#  'maga',
#  'httpstcozvrmgbce1c',
#  'join',
#  'thursday',
#  'afternoon',
#  '100pme',
#  'greenvill',
#  'north',
#  'carolina',
#  'pittgreenvill',
#  'airport',
#  'maga',
#  'httpstcoowg9psxwjz',
#  'join',
#  'tomorrow',
#  'tonight',
#  'wednesday',
#  'iowa',
#  'des',
#  'moin',
#  'intern',
#  'airport',
#  'httpstco92lmaondto',
#  'join',
#  'tonight',
#  '700pme',
#  'johnstown',
#  'pennsylvania',
#  'john',
#  'murtha',
#  'johnstowncambria',
#  'counti',
#  'airport',
#  'maga',
#  'httpstco8o9qhhdn1h',
#  'gmoomaw',
#  'virginia',
#  'voter',
#  'registr',
#  'system',
#  'report',
#  'problem',
#  'last',
#  'day',
#  'regist',
#  'vote',
#  'earli',
#  'vote',
#  'full',
#  'happen',
#  'us',
#  'rig',
#  'elect',
#  'httpstcomg0d9xuh1z',
#  'stimulus',
#  'go',
#  'big',
#  'go',
#  'home',
#  'radic',
#  'left',
#  'tri',
#  'hard',
#  'undermin',
#  'christoph',
#  'columbus',
#  'legaci',
#  'great',
#  'italian',
#  'open',
#  'new',
#  'chapter',
#  'histori',
#  'human',
#  'discov',
#  'america',
#  'oann',
#  'watch',
#  'actual',
#  'toni',
#  'pitch',
#  'arm',
#  'far',
#  'accur',
#  'prognost',
#  'problem',
#  'mask',
#  'longer',
#  'like',
#  'lockdown',
#  'came',
#  'trump',
#  'right',
#  'save',
#  '2000000',
#  'usa',
#  'live',
#  'httpstcoyylycsbz7a',
#  'love',
#  'peopl',
#  'lake',
#  'charl',
#  'louisiana',
#  'youv',
#  'hit',
#  'hard',
#  'often',
#  'feder',
#  'govern',
#  'help',
#  'work',
#  'fast',
#  'fema',
#  'usarmi',
#  'republican',
#  'provid',
#  'far',
#  'better',
#  'healthcar',
#  'democrat',
#  'far',
#  'lower',
#  'costand',
#  'alway',
#  'protect',
#  'peopl',
#  'preexist',
#  'condit',
#  'gop',
#  'rais',
#  '1',
#  'billion',
#  'dollar',
#  'winr',
#  'sinc',
#  'recent',
#  'found',
#  'novemb',
#  '3rd',
#  'import',
#  'elect',
#  'histori',
#  'countri',
#  'california',
#  'hire',
#  'pure',
#  'sleepi',
#  'joe',
#  'democrat',
#  'firm',
#  'count',
#  'harvest',
#  'vote',
#  'way',
#  'republican',
#  'get',
#  'fair',
#  'shake',
#  'lawyer',
#  'get',
#  'start',
#  'goplead',
#  'california',
#  'big',
#  'troubl',
#  'vote',
#  'trump',
#  'watch',
#  'greatest',
#  'comeback',
#  'also',
#  'new',
#  'york',
#  'illinoi',
#  'go',
#  'congratul',
#  'dan',
#  'breitbart',
#  'decim',
#  'busi',
#  'drudg',
#  'gone',
#  'way',
#  'nba',
#  'rate',
#  '70',
#  'peopl',
#  'want',
#  'truth',
#  'drudg',
#  'report',
#  'sold',
#  'suffer',
#  'massiv',
#  'nervous',
#  'breakdown',
#  'happen',
#  'foxnew',
#  'also',
#  'httpstcozr07xdhtnx',
#  'seanhann',
#  'hanniti',
#  'biden',
#  'disrespect',
#  'voter',
#  'courtpack',
#  'dodg',
#  'exclus',
#  'lawrencebjones3',
#  'talk',
#  'trump',
#  'support',
#  'fl',
#  'dbongino',
#  'tuesday',
#  'octob',
#  '13th',
#  '2020',
#  'barack',
#  'obama',
#  'corrupt',
#  'presid',
#  'us',
#  'histori',
#  'obamag',
#  'realdonaldtrump',
#  'httpstcoozyzlq2fqp',
#  'thank',
#  'greg',
#  'got',
#  'hoax',
#  'right',
#  'begin',
#  'httpstco3ql3naddd9',
#  'thank',
#  'nice',
#  'httpstco7glapstreb',
#  'senategop',
#  'today',
#  'day',
#  'confirmacb',
#  'httpstcoinq26kvona',
#  'senjoniernst',
#  'onli',
#  '100',
#  'year',
#  'ago',
#  'women',
#  'countri',
#  'given',
#  'right',
#  'vote',
#  'today',
#  'began',
#  'consid',
#  'ad',
#  'anoth',
#  'wo',
#  'alway',
#  'safe',
#  'kati',
#  'httpstcok5algsyuxj',
#  'dailybrief',
#  'week',
#  'go',
#  'elect',
#  'day',
#  'judg',
#  'ami',
#  'coney',
#  'barrett',
#  'made',
#  'case',
#  'serv',
#  'nation',
#  'highest',
#  'cour',
#  'danaperino',
#  'pleasur',
#  'interview',
#  'jon',
#  'ponder',
#  'matt',
#  'great',
#  'strong',
#  'militari',
#  'vet',
#  'great',
#  '2nd',
#  'amend',
#  'complet',
#  'total',
#  'endors',
#  'httpstcobrrr1zoxay',
#  'stillgray',
#  'dem',
#  'keep',
#  'claim',
#  'doesnt',
#  'happen',
#  'ryannmcenani',
#  'potus',
#  'realdonaldtrump',
#  'httpstcoyqomrt5bbo',
#  'wow',
#  'futur',
#  'vp',
#  'cool',
#  'httpstcol7lp69zsyl',
#  'trumpwarroom',
#  'white',
#  'race',
#  'superior',
#  'race',
#  'negro',
#  'race',
#  'inferior',
#  'race',
#  'said',
#  'democrat',
#  'senat',
#  'jame',
#  'eastland',
#  'joe',
#  'b',
#  'thesamsorbo',
#  'sen',
#  'ron',
#  'johnson',
#  'releas',
#  'report',
#  'biden',
#  'corrupt',
#  'china',
#  'ukrain',
#  'russia',
#  'fox',
#  'doesnt',
#  'report',
#  'thebabylonbe',
#  'california',
#  'mandat',
#  'food',
#  'must',
#  'consum',
#  'iv',
#  'ensur',
#  'mask',
#  'never',
#  'remov',
#  'httpstcomwfbnw5gzi',
#  'ozzmanosgood',
#  'may',
#  'sever',
#  'shock',
#  'democrat',
#  'expresss',
#  'poll',
#  'harbing',
#  'elect',
#  'realli',
#  'go',
#  'know',
#  'left',
#  'the171111',
#  'hiden',
#  'biden',
#  'obama',
#  'may',
#  'seal',
#  'team',
#  '6',
#  'kill',
#  'explos',
#  'cia',
#  'whistleblow',
#  'expos',
#  'biden',
#  'alleg',
#  'role',
#  'de',
#  'tatobin2',
#  'devast',
#  'power',
#  'ad',
#  'polit',
#  'oppon',
#  'ive',
#  'ever',
#  'seen',
#  'true',
#  'must',
#  'watch',
#  'rep',
#  'actbrigitt',
#  'vp',
#  'mikep',
#  'great',
#  'night',
#  'realdonaldtrump',
#  'httpstcogyx9kksswv',
#  'actbrigitt',
#  'red',
#  'wave',
#  'come',
#  'novemb',
#  '3rd',
#  'actbrigitt',
#  'wors',
#  'chris',
#  'wallac',
#  'donna',
#  'brazil',
#  'thank',
#  'httpstcoweyrvokwr1',
#  'senatordol',
#  'commiss',
#  'presidenti',
#  'debat',
#  'suppos',
#  'bipartisan',
#  'w',
#  'equal',
#  'number',
#  'rs',
#  'ds',
#  'know',
#  'republ',
#  'actbrigitt',
#  'contractor',
#  'took',
#  '47',
#  'year',
#  'build',
#  'construct',
#  'project',
#  'still',
#  'need',
#  'repair',
#  'would',
#  'give',
#  'f',
#  'scam',
#  'work',
#  'sleepi',
#  'joe',
#  'never',
#  'admit',
#  'rather',
#  'major',
#  'fact',
#  'httpstcoaleppjdi0i',
#  'thank',
#  'httpstco1h2fyp8xs8',
#  'actbrigitt',
#  'poll',
#  'presid',
#  'four',
#  'option',
#  'best',
#  'actbrigitt',
#  'joe',
#  'biden',
#  'said',
#  'voter',
#  'dont',
#  'deserv',
#  'know',
#  'hell',
#  'pack',
#  'court',
#  'joe',
#  'biden',
#  'doesnt',
#  'deserv',
#  'presid',
#  'actbrigitt',
#  'presid',
#  'trump',
#  'elect',
#  'america',
#  'big',
#  'troubl',
#  'economi',
#  'stagnant',
#  'militari',
#  'deplet',
#  'far',
#  'mani',
#  'chief',
#  'staff',
#  'said',
#  'idea',
#  'httpstcohdrbr930fr',
#  'actbrigitt',
#  'onli',
#  'way',
#  'prove',
#  'poll',
#  'fake',
#  'turn',
#  'vote',
#  'elect',
#  'day',
#  'like',
#  'never',
#  'befor',
#  'realdonaldtrump',
#  'httpstcohrevcqtya1',
#  'actbrigitt',
#  'worri',
#  'voter',
#  'fraudintegr',
#  'upcom',
#  'elect',
#  'think',
#  'biggest',
#  'threat',
#  'theleoterrel',
#  'anoth',
#  'lie',
#  'senkamalaharri',
#  'thank',
#  'god',
#  'lawyer',
#  'constitut',
#  'allow',
#  'nomin',
#  'approv',
#  'amycom',
#  'theleoterrel',
#  'pleas',
#  'listen',
#  'podcast',
#  'vote',
#  'risk',
#  'applepodcast',
#  'itun',
#  'httpstcozfvvylwuhf',
#  'theleoterrel',
#  'biden',
#  'bluff',
#  'member',
#  'black',
#  'delawar',
#  'church',
#  'dont',
#  'recal',
#  'biden',
#  'rais',
#  'httpstcobr0jn4wyaw',
#  'caesardaria',
#  'interest',
#  'comment',
#  'perspect',
#  'leo',
#  'terrel',
#  'almost',
#  '100',
#  'percent',
#  'everyon',
#  'know',
#  'new',
#  'jersey',
#  'equal',
#  'con',
#  'theleoterrel',
#  'sir',
#  'black',
#  'proud',
#  'american',
#  'love',
#  'america',
#  'vote',
#  'realdonaldtrump',
#  'foxnew',
#  'seanhann',
#  'theleoterrel',
#  'look',
#  'like',
#  'blacklivesmatt',
#  'antifa',
#  'laker',
#  'fan',
#  'polic',
#  'democrat',
#  'mayor',
#  'mayorofla',
#  'theleoterrel',
#  'kept',
#  'word',
#  'realdonaldtrump',
#  'watch',
#  'longtim',
#  'democrat',
#  'leo',
#  'terrel',
#  'keep',
#  'word',
#  'amp',
#  'offici',
#  'cast',
#  'vote',
#  'pres',
#  'theleoterrel',
#  'qualifi',
#  'becom',
#  'vicepresid',
#  ...]

# %%
len(stem2)
# Out:
# 23196

# %%
df = pd.DataFrame(stem2)

df = df[0].value_counts()

# %%
df.head(20)
# Out:
# biden              251
# trump              212
# presid             207
# realdonaldtrump    191
# amp                174
# vote               170
# great              169
# joe                160
# thank              126
# democrat           119
# peopl              118
# elect              106
# news                97
# state               93
# go                  92
# get                 92
# american            88
# win                 86
# job                 85
# new                 84
# Name: 0, dtype: int64

# %%
#This will give frequencies of our words

from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 2904, 2: 699, 3: 346, 4: 243, 5: 181, 6: 112, 7: 77, 8: 68, 9: 67, 10: 50, ...})

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This is a simple plot that shows the top 20 words being used
#df.plot(20)

df = df[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
